# %%
import yfinance as yf
import datetime
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import numpy as np
#import panel as pn
#from panel.interact import interact
#import plotly.express as px
#pn.extension("plotly")
#%matplotlib inline

import yfinance as yf 
from pypfopt import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
ASX_stock = input("Enter ASX20 Stock Symbol: ")

ASX_ = yf.Ticker(ASX_stock)

# get stock info
information =  ASX_.info

# drop None values from the info 
filtered = {k:v for k, v in information.items() if v is not None}
information.clear()
information.update(filtered)
information
# Out:
# Enter ASX20 Stock Symbol:  WOW
# {'zip': '80111',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 2000,
# ...

# %%
ANZ = yf.Ticker("ANZ.AX")

# get historical market data
df_ANZ = ANZ.history(start = '2011-1-1', end='2021-1-1')
df_ANZ.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_ANZ
# Out:
#                 Close
# Date
# 2011-01-04  13.349269
# 2011-01-05  13.291926
# 2011-01-06  13.240317
# 2011-01-07  13.142835
# 2011-01-10  13.165774
# ...               ...
# 2020-12-23  23.100000
# 2020-12-24  23.030001
# 2020-12-29  23.160000
# 2020-12-30  23.070000
# 2020-12-31  22.700001
#
# [2528 rows x 1 columns]

# %%
AMC = yf.Ticker("AMC.AX")

# get historical market data
df_AMC = AMC.history(start = '2011-1-1', end='2021-1-1')
df_AMC.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_AMC
# Out:
#                 Close
# Date
# 2011-01-04   3.844597
# 2011-01-05   3.788058
# 2011-01-06   3.765444
# 2011-01-07   3.771098
# 2011-01-10   3.765444
# ...               ...
# 2020-12-23  15.109823
# 2020-12-24  15.080137
# 2020-12-29  15.188984
# 2020-12-30  15.268146
# 2020-12-31  15.179089
#
# [2528 rows x 1 columns]

# %%
BHP = yf.Ticker("BHP.AX")

# get historical market data
df_BHP = BHP.history(start = '2011-1-1', end='2021-1-1')
df_BHP.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_BHP
# Out:
#                 Close
# Date
# 2011-01-04  26.426167
# 2011-01-05  26.044264
# 2011-01-06  26.119490
# 2011-01-07  25.818598
# 2011-01-10  25.720230
# ...               ...
# 2020-12-23  41.355705
# 2020-12-24  41.842819
# 2020-12-29  41.813587
# 2020-12-30  42.027920
# 2020-12-31  41.336224
#
# [2528 rows x 1 columns]

# %%
BXB = yf.Ticker("BXB.AX")

# get historical market data
df_BXB = BXB.history(start = '2011-1-1', end='2021-1-1')
df_BXB.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_BXB
# Out:
#                 Close
# Date
# 2011-01-04   4.573060
# 2011-01-05   4.553571
# 2011-01-06   4.741952
# 2011-01-07   4.702977
# 2011-01-10   4.735456
# ...               ...
# 2020-12-23  10.688060
# 2020-12-24  10.688060
# 2020-12-29  10.697928
# 2020-12-30  10.688060
# 2020-12-31  10.461075
#
# [2528 rows x 1 columns]

# %%
CBA = yf.Ticker("CBA.AX")

# get historical market data
df_CBA = CBA.history(start = '2011-1-1', end='2021-1-1')
df_CBA.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_CBA
# Out:
#                 Close
# Date
# 2011-01-04  28.836910
# 2011-01-05  28.426653
# 2011-01-06  28.449448
# 2011-01-07  28.426653
# 2011-01-10  28.517815
# ...               ...
# 2020-12-23  81.734398
# 2020-12-24  81.704918
# 2020-12-29  82.549973
# 2020-12-30  82.137268
# 2020-12-31  80.682991
#
# [2528 rows x 1 columns]

# %%
CSL = yf.Ticker("CSL.AX")

# get historical market data
df_CSL = AMC.history(start = '2011-1-1', end='2021-1-1')
df_CSL.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_CSL
# Out:
#                 Close
# Date
# 2011-01-04   3.844597
# 2011-01-05   3.788058
# 2011-01-06   3.765444
# 2011-01-07   3.771098
# 2011-01-10   3.765444
# ...               ...
# 2020-12-23  15.109823
# 2020-12-24  15.080137
# 2020-12-29  15.188984
# 2020-12-30  15.268146
# 2020-12-31  15.179089
#
# [2528 rows x 1 columns]

# %%
GMG = yf.Ticker("GMG.AX")

# get historical market data
df_GMG = GMG.history(start = '2011-1-1', end='2021-1-1')
df_GMG.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_GMG
# Out:
#                 Close
# Date
# 2011-01-04   2.254682
# 2011-01-05   2.219726
# 2011-01-06   2.167291
# 2011-01-07   2.167291
# 2011-01-10   2.184770
# ...               ...
# 2020-12-23  19.011087
# 2020-12-24  18.892021
# 2020-12-29  19.150000
# 2020-12-30  19.350000
# 2020-12-31  18.910000
#
# [2528 rows x 1 columns]

# %%
IAG = yf.Ticker("IAG.AX")

# get historical market data
df_IAG = IAG.history(start = '2011-1-1', end='2021-1-1')
df_IAG.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_IAG
# Out:
#                Close
# Date
# 2011-01-04  2.322943
# 2011-01-05  2.347141
# 2011-01-06  2.389486
# 2011-01-07  2.377388
# 2011-01-10  2.353190
# ...              ...
# 2020-12-23  4.726855
# 2020-12-24  4.756460
# 2020-12-29  4.776196
# 2020-12-30  4.716987
# 2020-12-31  4.638041
#
# [2528 rows x 1 columns]

# %%
MQG = yf.Ticker("MQG.AX")

# get historical market data
df_MQG = MQG.history(start = '2011-1-1', end='2021-1-1')
df_MQG.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_MQG
# Out:
#                  Close
# Date
# 2011-01-04   22.715950
# 2011-01-05   22.643490
# 2011-01-06   22.770292
# 2011-01-07   22.872944
# 2011-01-10   22.897091
# ...                ...
# 2020-12-23  138.880005
# 2020-12-24  140.110001
# 2020-12-29  140.520004
# 2020-12-30  140.490005
# 2020-12-31  138.479996
#
# [2528 rows x 1 columns]

# %%
NAB = yf.Ticker("NAB.AX")

# get historical market data
df_NAB = NAB.history(start = '2011-1-1', end='2021-1-1')
df_NAB.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_NAB
# Out:
#                 Close
# Date
# 2011-01-04  12.011321
# 2011-01-05  11.920672
# 2011-01-06  11.965997
# 2011-01-07  11.930744
# 2011-01-10  11.981106
# ...               ...
# 2020-12-23  22.980000
# 2020-12-24  23.000000
# 2020-12-29  23.110001
# 2020-12-30  23.030001
# 2020-12-31  22.600000
#
# [2528 rows x 1 columns]

# %%
NCM = yf.Ticker("NCM.AX")

# get historical market data
df_NCM = NCM.history(start = '2011-1-1', end='2021-1-1')
df_NCM.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_NCM
# Out:
#                 Close
# Date
# 2011-01-04  37.177162
# 2011-01-05  36.526218
# 2011-01-06  36.113651
# 2011-01-07  35.398525
# 2011-01-10  35.609402
# ...               ...
# 2020-12-23  25.963959
# 2020-12-24  26.053251
# 2020-12-29  25.825062
# 2020-12-30  25.725849
# 2020-12-31  25.577030
#
# [2528 rows x 1 columns]

# %%
RIO = yf.Ticker("RIO.AX")

# get historical market data
df_RIO = RIO.history(start = '2011-1-1', end='2021-1-1')
df_RIO.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_RIO
# Out:
#                  Close
# Date
# 2011-01-04   57.256138
# 2011-01-05   56.407402
# 2011-01-06   57.050568
# 2011-01-07   56.016197
# 2011-01-10   55.936634
# ...                ...
# 2020-12-23  113.791077
# 2020-12-24  114.286461
# 2020-12-29  114.217110
# 2020-12-30  114.712502
# 2020-12-31  112.780479
#
# [2528 rows x 1 columns]

# %%
SCG = yf.Ticker("SCG.AX")

# get historical market data
df_SCG = SCG.history(start = '2011-1-1', end='2021-1-1')
df_SCG.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_SCG
# Out:
#                Close
# Date
# 2011-01-04  1.476017
# 2011-01-05  1.493451
# 2011-01-06  1.470206
# 2011-01-07  1.470206
# 2011-01-10  1.510883
# ...              ...
# 2020-12-23  2.720000
# 2020-12-24  2.749247
# 2020-12-29  2.778495
# 2020-12-30  2.797993
# 2020-12-31  2.710251
#
# [2528 rows x 1 columns]

# %%
SUN = yf.Ticker("SUN.AX")

# get historical market data
df_SUN = SUN.history(start = '2011-1-1', end='2021-1-1')
df_SUN.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_SUN
# Out:
#                Close
# Date
# 2011-01-04  5.331303
# 2011-01-05  5.381957
# 2011-01-06  5.495928
# 2011-01-07  5.432611
# 2011-01-10  5.381957
# ...              ...
# 2020-12-23  9.694334
# 2020-12-24  9.674829
# 2020-12-29  9.723594
# 2020-12-30  9.655323
# 2020-12-31  9.499277
#
# [2528 rows x 1 columns]

# %%
TLS = yf.Ticker("TLS.AX")

# get historical market data
df_TLS = TLS.history(start = '2011-1-1', end='2021-1-1')
df_TLS.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_TLS
# Out:
#                Close
# Date
# 2011-01-04  1.639661
# 2011-01-05  1.633805
# 2011-01-06  1.627949
# 2011-01-07  1.622093
# 2011-01-10  1.627949
# ...              ...
# 2020-12-23  2.982043
# 2020-12-24  2.982043
# 2020-12-29  2.991950
# 2020-12-30  2.972136
# 2020-12-31  2.952322
#
# [2528 rows x 1 columns]

# %%
TCL = yf.Ticker("TCL.AX")

# get historical market data
df_TCL = TCL.history(start = '2011-1-1', end='2021-1-1')
df_TCL.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_TCL
# Out:
#                 Close
# Date
# 2011-01-04   3.132274
# 2011-01-05   3.169562
# 2011-01-06   3.188207
# 2011-01-07   3.244141
# 2011-01-10   3.262784
# ...               ...
# 2020-12-23  13.782332
# 2020-12-24  13.930742
# 2020-12-29  14.000000
# 2020-12-30  13.810000
# 2020-12-31  13.660000
#
# [2528 rows x 1 columns]

# %%
WES = yf.Ticker("WES.AX")

# get historical market data
df_WES = WES.history(start = '2011-1-1', end='2021-1-1')
df_WES.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_WES
# Out:
#                 Close
# Date
# 2011-01-04  12.826541
# 2011-01-05  12.528908
# 2011-01-06  12.516842
# 2011-01-07  12.581195
# 2011-01-10  12.549018
# ...               ...
# 2020-12-23  50.383244
# 2020-12-24  50.245583
# 2020-12-29  50.471741
# 2020-12-30  50.511066
# 2020-12-31  49.557289
#
# [2528 rows x 1 columns]

# %%
WBC = yf.Ticker("WBC.AX")

# get historical market data
df_WBC = WBC.history(start = '2011-1-1', end='2021-1-1')
df_WBC.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_WBC
# Out:
#                 Close
# Date
# 2011-01-04  13.108433
# 2011-01-05  13.002435
# 2011-01-06  13.061324
# 2011-01-07  13.043657
# 2011-01-10  12.996548
# ...               ...
# 2020-12-23  19.559999
# 2020-12-24  19.549999
# 2020-12-29  19.660000
# 2020-12-30  19.660000
# 2020-12-31  19.370001
#
# [2528 rows x 1 columns]

# %%
WPL = yf.Ticker("WPL.AX")

# get historical market data
df_WPL = WPL.history(start = '2011-1-1', end='2021-1-1')
df_WPL.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_WPL
# Out:
#                 Close
# Date
# 2011-01-04  26.155334
# 2011-01-05  25.910782
# 2011-01-06  26.277617
# 2011-01-07  26.155334
# 2011-01-10  26.283722
# ...               ...
# 2020-12-23  22.430622
# 2020-12-24  22.609510
# 2020-12-29  22.838091
# 2020-12-30  22.907658
# 2020-12-31  22.599573
#
# [2528 rows x 1 columns]

# %%
WOW = yf.Ticker("WOW.AX")

# get historical market data
df_WOW = WOW.history(start = '2011-1-1', end='2021-1-1')
df_WOW.drop(columns=['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits'],axis = 1, inplace=True)
df_WOW
# Out:
#                 Close
# Date
# 2011-01-04  18.112692
# 2011-01-05  17.976814
# 2011-01-06  17.902077
# 2011-01-07  17.847725
# 2011-01-10  17.908871
# ...               ...
# 2020-12-23  39.260399
# 2020-12-24  39.339333
# 2020-12-29  39.191334
# 2020-12-30  39.359066
# 2020-12-31  38.786789
#
# [2528 rows x 1 columns]

# %%
Portfolio2 = pd.concat([df_AMC, df_ANZ, df_BHP, df_BXB, df_CBA, 
                        df_CSL, df_GMG, df_IAG, df_MQG, df_NAB,
                        df_NCM, df_RIO, df_SCG, df_SUN, df_TLS, df_TCL, 
                        df_WES, df_WBC, df_WPL, df_WOW], axis="columns", join="inner")

Portfolio2.columns = ['AMC', 'ANZ' , 'BHP', 'BXB', 'CBA' , 'CSL', 'GMG', 'IAG', 'MQG', 'NAB', 'NAM', 'RIO' , 'SCG' , 'SUN', 'TLS', 'TCL', 'WES', 'WBC', 'WPL', 'WOW']
Portfolio2
# Out:
#                   AMC        ANZ        BHP        BXB        CBA        CSL  \
# Date
# 2011-01-04   3.844597  13.349269  26.426167   4.573060  28.836910   3.844597
# 2011-01-05   3.788058  13.291926  26.044264   4.553571  28.426653   3.788058
# 2011-01-06   3.765444  13.240317  26.119490   4.741952  28.449448   3.765444
# 2011-01-07   3.771098  13.142835  25.818598   4.702977  28.426653   3.771098
# 2011-01-10   3.765444  13.165774  25.720230   4.735456  28.517815   3.765444
# ...               ...        ...        ...        ...        ...        ...
# 2020-12-23  15.109823  23.100000  41.355705  10.688060  81.734398  15.109823
# 2020-12-24  15.080137  23.030001  41.842819  10.688060  81.704918  15.080137
# 2020-12-29  15.188984  23.160000  41.813587  10.697928  82.549973  15.188984
# 2020-12-30  15.268146  23.070000  42.027920  10.688060  82.137268  15.268146
# 2020-12-31  15.179089  22.700001  41.336224  10.461075  80.682991  15.179089
#
# ...

# %%
# Optimize the portfolio 
# Caluculate the expected anualized returns and sample covariance

mu = expected_returns.mean_historical_return(Portfolio2)
S = risk_models.sample_cov(Portfolio2)
mu
# Out:
# AMC    0.146765
# ANZ    0.054370
# BHP    0.045625
# BXB    0.086019
# CBA    0.108050
# CSL    0.146765
# GMG    0.236246
# IAG    0.071387
# MQG    0.197535
# NAB    0.065064
# NAM   -0.036609
# RIO    0.069941
# SCG    0.062475
# SUN    0.059293
# TLS    0.060401
# TCL    0.158196
# WES    0.144293
# WBC    0.039707
# WPL   -0.014466
# WOW    0.078893
# dtype: float64

# %%
#Optimized for the miximal Sharpe ratio 
ef = EfficientFrontier(mu, S)  #create the Efficient Frontier Object
weights = ef.max_sharpe()

cleaned_weights = ef.clean_weights()
ef.save_weights_to_file("weights.txt")  # saves to file
print(cleaned_weights)
# Out:
# OrderedDict([('AMC', 0.10784), ('ANZ', 0.0), ('BHP', 0.0), ('BXB', 0.0), ('CBA', 0.0), ('CSL', 0.10784), ('GMG', 0.35177), ('IAG', 0.0), ('MQG', 0.07475), ('NAB', 0.0), ('NAM', 0.0), ('RIO', 0.0), ('SCG', 0.0), ('SUN', 0.0), ('TLS', 0.0), ('TCL', 0.20634), ('WES', 0.15146), ('WBC', 0.0), ('WPL', 0.0), ('WOW', 0.0)])

# %%
ef.portfolio_performance(verbose = True)
# Out:
# Expected annual return: 18.4%
# Annual volatility: 16.7%
# Sharpe Ratio: 0.98
# (0.18402089799921414, 0.16732651393172115, 0.9802445180095255)

# %%
# pip install pulp
# pip install cvxopt (FOR solver GLPK_MI)

# Get the discrete allocation of each share per share per stock 
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices

initial_investment = 10000
latest_prices = get_latest_prices(Portfolio2)
weights = cleaned_weights 

da = DiscreteAllocation(weights, latest_prices, total_portfolio_value = initial_investment)
allocation, leftover = da.lp_portfolio()
print('Discrete allocation', allocation)
print('Funds Remaining: $' , leftover)
# Out:
# Discrete allocation {'AMC': 71, 'CSL': 72, 'GMG': 186, 'MQG': 5, 'TCL': 152, 'WES': 31}
# Funds Remaining: $ 7.134441375732422

# %%
optimal_portfolio2 = pd.concat([df_AMC, df_CSL, df_GMG, df_MQG, df_TCL, df_WES], axis="columns", join="inner")
optimal_portfolio2.columns = ['AMC',  'CSL', 'GMG',  'MQG', 'TCL', 'WES']
optimal_portfolio2
# Out:
#                   AMC        CSL        GMG         MQG        TCL        WES
# Date
# 2011-01-04   3.844597   3.844597   2.254682   22.715950   3.132274  12.826541
# 2011-01-05   3.788058   3.788058   2.219726   22.643490   3.169562  12.528908
# 2011-01-06   3.765444   3.765444   2.167291   22.770292   3.188207  12.516842
# 2011-01-07   3.771098   3.771098   2.167291   22.872944   3.244141  12.581195
# 2011-01-10   3.765444   3.765444   2.184770   22.897091   3.262784  12.549018
# ...               ...        ...        ...         ...        ...        ...
# 2020-12-23  15.109823  15.109823  19.011087  138.880005  13.782332  50.383244
# 2020-12-24  15.080137  15.080137  18.892021  140.110001  13.930742  50.245583
# 2020-12-29  15.188984  15.188984  19.150000  140.520004  14.000000  50.471741
# 2020-12-30  15.268146  15.268146  19.350000  140.490005  13.810000  50.511066
# 2020-12-31  15.179089  15.179089  18.910000  138.479996  13.660000  49.557289
#
# [2528 rows x 6 columns]

# %%
daily_returns = optimal_portfolio2.pct_change()

weights = [0.10784, 0.10784, 0.35177, 0.07475, 0.20634, 0.15146]

portfolio2_returns = daily_returns.dot(weights)

portfolio2_returns.plot()

# %%
cumulative_returns = (1 + portfolio2_returns).cumprod() - 1

cumulative_returns.plot()
